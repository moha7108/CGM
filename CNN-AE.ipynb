# %% [markdown]
# # Convolutional Autoencoder

# %% [markdown]
# ## Import statements + Device

# %%
import torch
import torch.optim as optim
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import torchvision.transforms as transforms
from torch.utils.data import Dataset
from torchvision import datasets
from torch.utils.data.sampler import SubsetRandomSampler
import matplotlib.pyplot as plt
from utils import print_np_array_properties
# %matplotlib inline


device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f'Available Device: {device}')

def split_validation(data):
    
    valid_len = len(data)//2
    test_len = len(data) - valid_len
    valid_data, test_data = torch.utils.data.random_split(data, [valid_len , test_len])
    
    return valid_data, test_data


def imshow(img):
    # img = img/2 +0.5
    
    plt.imshow(np.transpose(img, (1,2,0))) # convert from tensor to image
# Out:
# Available Device: cuda

# %% [markdown]
# ## Dataset

# %%
num_workers = 0
# how many samples per batch to load
batch_size = 20
# percentage of training set to use as validation
valid_size = 0.2


## Define preprocessing transformation applied to data
transform = transforms.Compose([
    transforms.ToTensor()
    ])

train_data = datasets.CIFAR10(
    root='data',
    train=True,
    download=True,
    transform=transform)

validation_data = datasets.CIFAR10( 
    root='data',
    train=False,
    download=True,
    transform=transform)

valid_data, test_data = split_validation(validation_data)


train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, num_workers=num_workers, shuffle=True)
valid_loader = torch.utils.data.DataLoader(valid_data, batch_size=batch_size, num_workers=num_workers, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=batch_size, num_workers=num_workers, shuffle=True)

classes = ['airplane', 'automobile', 'bird', 'cat', 'deer',
           'dog', 'frog', 'horse', 'ship', 'truck']


dataiter = iter(train_loader)
images, label = next(dataiter)

print(images.shape)

fig = plt.figure(figsize=(25,4))

for i in np.arange(batch_size):
    ax = fig.add_subplot(2, int(batch_size/2), i+1, xticks=[], yticks=[])
    imshow(images[i])
    ax.set_title(classes[label[i]])
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# torch.Size([20, 3, 32, 32])

# %% [markdown]
# ## Convolutional Autoencoder Architecture

# %%
class ConvAE(nn.Module):
    def __init__(self):
        
        super(ConvAE, self).__init__()
        
        self.encoder = nn.Sequential( 
            
            nn.Conv2d(3, 32, 3, stride=1, padding=1),
            nn.ReLU(),
            
            nn.Conv2d(32, 32, 3, stride=1, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),
            
            nn.Conv2d(32, 32, 3, stride=1, padding=1),
            nn.ReLU(),
            
            nn.Conv2d(32, 32, 3, stride=1, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),
            
#             nn.Conv2d(32, 10, 3, stride=1, padding=1),
#             nn.ReLU(),
#             nn.MaxPool2d(2, 2),
            
#             nn.Conv2d(10, 10, 3, stride=1, padding=1),
#             nn.ReLU(),
            
#             nn.Conv2d(10, 10, 3, stride=1, padding=1),
#             nn.ReLU(),
            
        )
        
        self.decoder = nn.Sequential(
            
            # nn.ConvTranspose2d(10, 32, 2, stride=2),
            # nn.ReLU(),
            
            nn.ConvTranspose2d(32, 16, 2, stride=2),
            nn.ReLU(),
            
            nn.Conv2d(16, 16, 3, stride=1, padding=1),
            nn.ReLU(),
            
            nn.Conv2d(16, 16, 3, stride=1, padding=1),
            nn.ReLU(),
            
            nn.ConvTranspose2d(16, 3, 2, stride=2),
            nn.ReLU(),
            
        )
        
    def forward(self,x):
        z = self.encoder(x)
        # print_np_array_properties(z)
        x = self.decoder(z)
        
        return x, z

# %% [markdown]
# ### Define Model and optimizer

# %%
model = ConvAE().to(device)

print(model)

x,z= model(images[i].to(device))

print_np_array_properties(z)
print_np_array_properties(x)

loss_func = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.01)
# Out:
# ConvAE(
#   (encoder): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU()
#     (7): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU()
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (decoder): Sequential(
#     (0): ConvTranspose2d(32, 16, kernel_size=(2, 2), stride=(2, 2))
#     (1): ReLU()
#     (2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): ReLU()
#     (6): ConvTranspose2d(16, 3, kernel_size=(2, 2), stride=(2, 2))
#     (7): ReLU()
#   )
# )
# =============== np array Properties =============
#
# np array:
#  tensor([[[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          ...,
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#
#         [[0.0595, 0.0563, 0.0563,  ..., 0.0564, 0.0563, 0.0503],
#          [0.0396, 0.0453, 0.0442,  ..., 0.0449, 0.0436, 0.0365],
#          [0.0388, 0.0452, 0.0446,  ..., 0.0446, 0.0437, 0.0366],
#          ...,
#          [0.0469, 0.0528, 0.0514,  ..., 0.0523, 0.0437, 0.0316],
#          [0.0310, 0.0367, 0.0351,  ..., 0.0312, 0.0328, 0.0320],
#          [0.0230, 0.0362, 0.0366,  ..., 0.0313, 0.0309, 0.0290]],
#
#         [[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          ...,
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#
#         ...,
#
#         [[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          ...,
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#
#         [[0.0555, 0.0452, 0.0445,  ..., 0.0445, 0.0443, 0.0445],
#          [0.0655, 0.0484, 0.0446,  ..., 0.0457, 0.0460, 0.0401],
#          [0.0635, 0.0444, 0.0430,  ..., 0.0426, 0.0424, 0.0371],
#          ...,
#          [0.0555, 0.0472, 0.0433,  ..., 0.0401, 0.0394, 0.0397],
#          [0.0623, 0.0383, 0.0359,  ..., 0.0331, 0.0306, 0.0371],
#          [0.0607, 0.0522, 0.0504,  ..., 0.0500, 0.0508, 0.0491]],
#
#         [[0.0086, 0.0168, 0.0174,  ..., 0.0181, 0.0190, 0.0183],
#          [0.0264, 0.0219, 0.0195,  ..., 0.0186, 0.0171, 0.0082],
#          [0.0305, 0.0202, 0.0194,  ..., 0.0227, 0.0203, 0.0078],
#          ...,
#          [0.0323, 0.0426, 0.0434,  ..., 0.0327, 0.0191, 0.0000],
#          [0.0207, 0.0156, 0.0105,  ..., 0.0048, 0.0000, 0.0000],
#          [0.0214, 0.0140, 0.0171,  ..., 0.0050, 0.0000, 0.0000]]],
#        device='cuda:0', grad_fn=<MaxPool2DWithIndicesBackward0>)
# np array_dtype: torch.float32
# np array_shape: torch.Size([32, 8, 8])
# np array_size: <built-in method size of Tensor object at 0x7f89739fe3e0>
#
# ================================================
# =============== np array Properties =============
#
# np array:
#  tensor([[[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          ...,
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#
#         [[0.1613, 0.1959, 0.1639,  ..., 0.1963, 0.1652, 0.1942],
#          [0.2389, 0.1727, 0.2364,  ..., 0.1698, 0.2415, 0.1787],
#          [0.1609, 0.2044, 0.1589,  ..., 0.2029, 0.1634, 0.2020],
#          ...,
#          [0.2440, 0.1707, 0.2401,  ..., 0.1687, 0.2404, 0.1747],
#          [0.1643, 0.2028, 0.1599,  ..., 0.2027, 0.1613, 0.2004],
#          [0.2449, 0.1727, 0.2384,  ..., 0.1782, 0.2339, 0.1818]],
#
#         [[0.2443, 0.1990, 0.2419,  ..., 0.2054, 0.2484, 0.2003],
#          [0.2541, 0.2396, 0.2571,  ..., 0.2351, 0.2569, 0.2356],
#          [0.2416, 0.1867, 0.2410,  ..., 0.1924, 0.2481, 0.1941],
#          ...,
#          [0.2581, 0.2388, 0.2554,  ..., 0.2312, 0.2516, 0.2324],
#          [0.2521, 0.1845, 0.2505,  ..., 0.1891, 0.2490, 0.1984],
#          [0.2514, 0.2353, 0.2493,  ..., 0.2287, 0.2484, 0.2332]]],
#        device='cuda:0', grad_fn=<ReluBackward0>)
# np array_dtype: torch.float32
# np array_shape: torch.Size([3, 32, 32])
# np array_size: <built-in method size of Tensor object at 0x7f89739fed40>
#
# ================================================

# %%
n_epochs=60

valid_loss_min = np.Inf

for epoch in range(1, n_epochs):
    
    train_loss=0.0
    valid_loss=0.0
    
    ## Training Step
    model.train()
    for images, _ in train_loader:
        
        images = images.to(device)
        
        optimizer.zero_grad() # clar the gradients of all optimized variables
        x,z = model(images) # Forward pass
        
        loss = loss_func(x, images) # calculate loss of the forward pass
        
        loss.backward() #calculate gradients based on the loss
        
        optimizer.step() # update weights
        
        train_loss += loss.item()*images.size(0)
    ## Validation Step
    
    model.eval()
    for images, _ in valid_loader:
        images = images.to(device)
        
        x,z = model(images) # forward pass
        
        loss = loss_func(x, images)
        
        valid_loss += loss.item() * images.size(0)
    
    # calculate Average loss
    train_loss = train_loss/len(train_loader.dataset) 
    valid_loss = valid_loss/len(valid_loader.dataset)
    
    #Print progress statement
    print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(epoch, train_loss, valid_loss))
    
    #Save model with the lowest validation loss
    if valid_loss <= valid_loss_min:
        print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(valid_loss_min, valid_loss))
        torch.save(model.state_dict(), './data/ConvAE_cifar.pt')
        valid_loss_min = valid_loss
# Out:
# Epoch: 1 	Training Loss: 0.013309 	Validation Loss: 0.009568
# Validation loss decreased (inf --> 0.009568).  Saving model ...
# Epoch: 2 	Training Loss: 0.007195 	Validation Loss: 0.005218
# Validation loss decreased (0.009568 --> 0.005218).  Saving model ...
# Epoch: 3 	Training Loss: 0.005214 	Validation Loss: 0.005038
# Validation loss decreased (0.005218 --> 0.005038).  Saving model ...
# Epoch: 4 	Training Loss: 0.005002 	Validation Loss: 0.004708
# Validation loss decreased (0.005038 --> 0.004708).  Saving model ...
# Epoch: 5 	Training Loss: 0.004930 	Validation Loss: 0.004601
# Validation loss decreased (0.004708 --> 0.004601).  Saving model ...
# Epoch: 6 	Training Loss: 0.004889 	Validation Loss: 0.004815
# Epoch: 7 	Training Loss: 0.004736 	Validation Loss: 0.004574
# Validation loss decreased (0.004601 --> 0.004574).  Saving model ...
# Epoch: 8 	Training Loss: 0.004721 	Validation Loss: 0.004532
# Validation loss decreased (0.004574 --> 0.004532).  Saving model ...
# Epoch: 9 	Training Loss: 0.004648 	Validation Loss: 0.004408
# Validation loss decreased (0.004532 --> 0.004408).  Saving model ...
# Epoch: 10 	Training Loss: 0.004666 	Validation Loss: 0.004436
# Epoch: 11 	Training Loss: 0.004598 	Validation Loss: 0.004343
# Validation loss decreased (0.004408 --> 0.004343).  Saving model ...
# Epoch: 12 	Training Loss: 0.004559 	Validation Loss: 0.004710
# Epoch: 13 	Training Loss: 0.004581 	Validation Loss: 0.004520
# Epoch: 14 	Training Loss: 0.004559 	Validation Loss: 0.004375
# Epoch: 15 	Training Loss: 0.004537 	Validation Loss: 0.004529
# Epoch: 16 	Training Loss: 0.004526 	Validation Loss: 0.005418
# Epoch: 17 	Training Loss: 0.004521 	Validation Loss: 0.004273
# Validation loss decreased (0.004343 --> 0.004273).  Saving model ...
# Epoch: 18 	Training Loss: 0.004532 	Validation Loss: 0.004383
# Epoch: 19 	Training Loss: 0.004504 	Validation Loss: 0.004895
# Epoch: 20 	Training Loss: 0.004524 	Validation Loss: 0.004296
# Epoch: 21 	Training Loss: 0.004511 	Validation Loss: 0.004595
# Epoch: 22 	Training Loss: 0.004500 	Validation Loss: 0.004436
# Epoch: 23 	Training Loss: 0.004512 	Validation Loss: 0.004388
# Epoch: 24 	Training Loss: 0.004510 	Validation Loss: 0.004277
# Epoch: 25 	Training Loss: 0.004490 	Validation Loss: 0.004399
# Epoch: 26 	Training Loss: 0.004495 	Validation Loss: 0.004530
# Epoch: 27 	Training Loss: 0.004498 	Validation Loss: 0.004340
# Epoch: 28 	Training Loss: 0.004484 	Validation Loss: 0.004221
# Validation loss decreased (0.004273 --> 0.004221).  Saving model ...
# Epoch: 29 	Training Loss: 0.004479 	Validation Loss: 0.005331
# Epoch: 30 	Training Loss: 0.004523 	Validation Loss: 0.004518
# Epoch: 31 	Training Loss: 0.004456 	Validation Loss: 0.005379
# Epoch: 32 	Training Loss: 0.004476 	Validation Loss: 0.004365
# Epoch: 33 	Training Loss: 0.004485 	Validation Loss: 0.004642
# Epoch: 34 	Training Loss: 0.004462 	Validation Loss: 0.004506
# Epoch: 35 	Training Loss: 0.004451 	Validation Loss: 0.004291
# Epoch: 36 	Training Loss: 0.004459 	Validation Loss: 0.004417
# Epoch: 37 	Training Loss: 0.004481 	Validation Loss: 0.004457
# Epoch: 38 	Training Loss: 0.004443 	Validation Loss: 0.004297
# Epoch: 39 	Training Loss: 0.004441 	Validation Loss: 0.004359
# Epoch: 40 	Training Loss: 0.004473 	Validation Loss: 0.004322
# Epoch: 41 	Training Loss: 0.004488 	Validation Loss: 0.004481
# Epoch: 42 	Training Loss: 0.004453 	Validation Loss: 0.004382
# Epoch: 43 	Training Loss: 0.004448 	Validation Loss: 0.004332
# Epoch: 44 	Training Loss: 0.004445 	Validation Loss: 0.004530
# Epoch: 45 	Training Loss: 0.004461 	Validation Loss: 0.004758
# Epoch: 46 	Training Loss: 0.004452 	Validation Loss: 0.004270
# Epoch: 47 	Training Loss: 0.004453 	Validation Loss: 0.004249
# Epoch: 48 	Training Loss: 0.004449 	Validation Loss: 0.004344
# Epoch: 49 	Training Loss: 0.004487 	Validation Loss: 0.004293
# Epoch: 50 	Training Loss: 0.004451 	Validation Loss: 0.004283
# Epoch: 51 	Training Loss: 0.004467 	Validation Loss: 0.004197
# Validation loss decreased (0.004221 --> 0.004197).  Saving model ...
# Epoch: 52 	Training Loss: 0.004453 	Validation Loss: 0.004493
# Epoch: 53 	Training Loss: 0.004459 	Validation Loss: 0.004218
# Epoch: 54 	Training Loss: 0.004429 	Validation Loss: 0.004424
# Epoch: 55 	Training Loss: 0.004472 	Validation Loss: 0.004360
# Epoch: 56 	Training Loss: 0.004461 	Validation Loss: 0.004376
# Epoch: 57 	Training Loss: 0.004441 	Validation Loss: 0.004274
# Epoch: 58 	Training Loss: 0.004448 	Validation Loss: 0.004400
# Epoch: 59 	Training Loss: 0.004457 	Validation Loss: 0.004369

# %% [markdown]
# ### Test output

# %%
model.load_state_dict(torch.load('./data/ConvAE_cifar.pt'))

# obtain one batch of test images
dataiter = iter(test_loader)
images, labels = next(dataiter)

# get sample outputs
output, _ = model(images.to(device))
# prep images for display
images = images.numpy()

# output is resized into a batch of iages
output = output.to('cpu').view(batch_size, 3, 32, 32)
# use detach when it's an output that requires_grad
output = output.detach().numpy()

# plot the first ten input images and then reconstructed images
fig, axes = plt.subplots(nrows=2, ncols=10, sharex=True, sharey=True, figsize=(25,4))

# input images on top row, reconstructions on bottom
for images, row in zip([images, output], axes):
    for img, ax in zip(images, row):
        ax.imshow(np.transpose(img, (1,2,0)))
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
